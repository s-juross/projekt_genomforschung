# %% [markdown]
# # Data exploration big file

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\Juli\Documents\Master\Projekt Genomforschung\GDSC2_public_raw_data_27Oct23\GDSC2_public_raw_data_27Oct23.csv")

# %%
df.head()
# Out:
#   RESEARCH_PROJECT  BARCODE  SCAN_ID          DATE_CREATED  \
# 0          GDSC_SA     3230     2945  2015-02-13T00:00:00Z
# 1          GDSC_SA     3230     2945  2015-02-13T00:00:00Z
# 2          GDSC_SA     3230     2945  2015-02-13T00:00:00Z
# 3          GDSC_SA     3230     2945  2015-02-13T00:00:00Z
# 4          GDSC_SA     3230     2945  2015-02-13T00:00:00Z
#
#               SCAN_DATE  CELL_ID  MASTER_CELL_ID  COSMIC_ID CELL_LINE_NAME  \
# 0  2015-02-17T00:00:00Z     4712             198     753608          PC-14
# 1  2015-02-17T00:00:00Z     4712             198     753608          PC-14
# 2  2015-02-17T00:00:00Z     4712             198     753608          PC-14
# 3  2015-02-17T00:00:00Z     4712             198     753608          PC-14
# 4  2015-02-17T00:00:00Z     4712             198     753608          PC-14
#
#   SANGER_MODEL_ID  SEEDING_DENSITY  DRUGSET_ID ASSAY  DURATION  POSITION  \
# 0       SIDM00237              250         159   Glo         4         1
# ...
